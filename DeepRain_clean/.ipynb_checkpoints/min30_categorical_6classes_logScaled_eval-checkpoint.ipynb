# %%
from min30_categorical_6classes_logScaled import *
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
from PIL import Image
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot
from Utils.eval import *
from tensorflow.keras.optimizers import Adam
import keras.backend.tensorflow_backend
from keras.backend import clear_session
from tensorflow.keras.models import Model,Sequential
from Utils.Dataset import getData
from Utils.transform import cutOut,Normalize,LogBin,LinBin
import os
# Out:
# Num GPUs: 1
# Using TensorFlow backend.

# %%
source_model,modelpath,train,test = getModel(False)
source_model.summary()
predictions = source_model.layers[-2].output
model = Model(inputs=source_model.inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 20)   920         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 20)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 20)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 25)   4525        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 25)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 25)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 25)   5650        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 25)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 25)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 25)   5650        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 25)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 25)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 12, 12, 25)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 12, 50)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 24, 24, 50)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 75)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 48, 48, 75)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 100)  0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 96, 96, 100)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 120)  0           activation[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 90, 90, 1)    5881        concatenate_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8100)         0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1036928     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 28672)        3698688     dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1, 7) 0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softmax (TensorFlow [(None, 64, 64, 1, 7 0           reshape[0][0]
# __________________________________________________________________________________________________
# DistributionLayer (Distribution ((None, 64, 64, 1),  0           tf_op_layer_Softmax[0][0]
# ==================================================================================================
# Total params: 4,758,242
# Trainable params: 4,758,242
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 20)   920         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 20)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 20)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 25)   4525        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 25)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 25)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 25)   5650        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 25)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 25)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 25)   5650        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 25)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 25)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 12, 12, 25)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 12, 50)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 24, 24, 50)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 75)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 48, 48, 75)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 100)  0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 96, 96, 100)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 120)  0           activation[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 90, 90, 1)    5881        concatenate_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8100)         0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1036928     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 28672)        3698688     dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1, 7) 0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softmax (TensorFlow [(None, 64, 64, 1, 7 0           reshape[0][0]
# ==================================================================================================
# Total params: 4,758,242
# Trainable params: 4,758,242
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history_path = os.path.join(modelpath,MODELNAME+"_history.png")
figure(num=None, figsize=(10, 30), dpi=80, facecolor='w', edgecolor='k')
loss = np.array(Image.open(history_path))
plt.imshow(loss)
plt.axis('off')
plt.show()

x_transform = [Normalize(0.0033127920560417023,0.012673124326485102)]
y_transform = [cutOut([16,80,16,80]),LogBin()]

train,test = getData(BATCH_SIZE,
                         DIMENSION,CHANNELS,
                         timeToPred=30,
                         y_transform=y_transform,
                         x_transform=x_transform)

# %%
history_path = os.path.join(modelpath,MODELNAME+"_history")
laststate = getBestState(modelpath,history_path)
epoch = laststate["epoch"]
model.load_weights(laststate["modelpath"])
test.setWiggle_off()

# %%
def getFreshSet(batch_size=1):
    #x_transform = [Normalize(0.007742631458799244, 0.015872015890555563 )]
    
    train,test = getData(batch_size,
                         DIMENSION,CHANNELS,
                         timeToPred=30,
                         x_transform = x_transform,
                         y_transform=y_transform)
    return train,test

# %%
def categorical(t):
    return tfp.distributions.Independent(
            tfd.Categorical(logits=tf.math.log(t[...,:,:,:]))
            ,name="categorical",reinterpreted_batch_ndims=0 )

pred = None
label = None
pred = 20
test.on_epoch_end()
mean = []
stdev = []
label = []
predictions = []
train,test = getFreshSet(50)
for x,y in train:
    print(x.shape,y.shape)

test.setWiggle_off()
atm = []
for (x,y) in test:
    for i in range(BATCH_SIZE):
        print(y,end="\r")
        if i < 10:
            continue
        if y.max() <= 5:
            continue
        pred = model(np.array([x[i,:,:,:]]))
        pred = categorical(pred)
        #p= 0
        p = np.arange(1,7)
        m = pred.prob(p)

        max_ = np.argmax(m[:,:,:,1:],axis=-1)


        m = pred.prob(0)
        mask = (m > 0.5)
        #print(mask.shape,max_.shape)
        #max_[mask] = 0
        
        mean.append(max_)
        #stdev.append(pred.sample())
        label.append(y[i,:,:,:])
        predictions.append((pred,y[i:,:,:]))
        atm.append(x[i,:,:,-1:])
        if len(label) == 20:
            break
    
    if len(label) == 20:
        break
# Out:
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# (50, 96, 96, 5) (50, 0, 0, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c8d38dbfc159> in <module>
#      13 predictions = []
#      14 train,test = getFreshSet(50)
# ---> 15 for x,y in train:
#      16     print(x.shape,y.shape)
#      17
#
# ~/anaconda3/envs/DeepRain/lib/python3.7/site-packages/tensorflow/python/keras/utils/data_utils.py in __iter__(self)
#     469   def __iter__(self):
#     470     """Create a generator that iterate over the Sequence."""
# --> 471     for item in (self[i] for i in range(len(self))):
#     472       yield item
#     473
#
# ~/anaconda3/envs/DeepRain/lib/python3.7/site-packages/tensorflow/python/keras/utils/data_utils.py in <genexpr>(.0)
#     469   def __iter__(self):
#     470     """Create a generator that iterate over the Sequence."""
# --> 471     for item in (self[i] for i in range(len(self))):
#     472       yield item
#     473
#
# ~/Dokumente/Teamprojekt/DeepRain2/DeepRain_clean/Utils/Dataset.py in __getitem__(self, index)
#     377
#     378         for id in id_list:
# --> 379             x,y = self.__data_generation(id)
#     380
#     381             X.append(x)
#
# ~/Dokumente/Teamprojekt/DeepRain2/DeepRain_clean/Utils/Dataset.py in __data_generation(self, index)
#     309         if not self.fillSteps:
#     310             i = end + self.label_Offset
# --> 311             Y = [self.Y_Processing(i)]
#     312         else:
#     313             Y = [self.Y_Processing(i) for i in range(end,end+self.label_Offset)]
#
# ~/Dokumente/Teamprojekt/DeepRain2/DeepRain_clean/Utils/Dataset.py in Y_Processing(self, index)
#     292     def Y_Processing(self,index):
#     293
# --> 294         img = cv2.imread(self.data[index][0],0)
#     295         if not self.Wiggle_off:
#     296             img = self.Wiggle(img)
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(20, 3, figsize=(16,8*10),dpi=64)
#fig.set_title(["mean","stdev","label"])
t = cutOut([96,160,96,160])
for batch,img in enumerate(mean):
    if batch == 20:
        break
    axes[batch,2].imshow(img[0,:,:],cmap="gray")
    #axes[batch,3].imshow(stdev[batch][0,:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch][:,:,0],cmap="gray")
    axes[batch,0].imshow(t(atm[batch][:,:,-1]),cmap="gray")
plt.show()
