# %%
from Utils.transform import ImageToPatches
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np

path = "./Data/RAW/MonthPNGData/YW2017.002_201501/1501020120.png"
img = np.array(Image.open(path))

# %%
#fig, axs = plt.subplots(1,1, figsize=(110,90),dpi=64)
#plt.imshow(img)
#plt.show()

# %%
from Utils.transform import ImageToPatches
patchesCutter = ImageToPatches(outputsize=(128,128),inputsize=(512,512))
#x,y = patchesCutter(img,img)
x,y = patchesCutter(img,img)

# %%
fig, axs = plt.subplots(x.shape[0], x.shape[1], figsize=(150,150),dpi=64)

    
for i in range(x.shape[0]):
    for j in range(x.shape[1]):
        axs[i,j].imshow(x[i,j])

# %%
fig, axs = plt.subplots(x.shape[0], x.shape[1], figsize=(110,90),dpi=64)

for i in range(y.shape[0]):
    for j in range(y.shape[1]):
        axs[i,j].imshow(y[i,j])

# %%
print(x.shape,y.shape)
# Out:
# (9, 8, 512, 512) (9, 8, 128, 128)
