# %%
from Utils.loadset import getDataSet
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np


tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions
import os
from trainer import Trainer
try:
    from Utils.connection_cfg import *
except Exception as e:
    PSWD = None
    USRN = None
    
from Utils.Data import dataWrapper
from Utils.transform import ToCategorical, cutOut
# Out:
# Num GPUs Available: 1
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)
#y_test = y_test.reshape(y_train.shape[0],28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# (60000, 28, 28)

# %%
def test_ae(input_shape,activation="relu"):
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer = Conv2D(1, kernel_size=(3, 3), padding="same") (layer)
    
    model = Model(inputs=inputs, outputs=layer)
    return model

# %%
print(x_train.shape)
model = test_ae([28,28,1])
model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=Adam( lr= 1e-5 ))
model.summary()
# Out:
# (60000, 28, 28, 1)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_5 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_7 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 1)         289
# =================================================================
# Total params: 52,001
# Trainable params: 51,649
# Non-trainable params: 352
# _________________________________________________________________

# %%
model.fit(x_train,x_train,epochs=200,batch_size=400)
# Out:
# Train on 60000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 4s 72us/sample - loss: 1.4541
# Epoch 2/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.7264
# Epoch 3/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.4385
# Epoch 4/200
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.2999
# Epoch 5/200
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.2232
# Epoch 6/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.1753
# Epoch 7/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.1428
# Epoch 8/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.1195
# Epoch 9/200
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.1021
# Epoch 10/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0887
# Epoch 11/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0782
# Epoch 12/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0699
# Epoch 13/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0632
# Epoch 14/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0577
# Epoch 15/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0532
# Epoch 16/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0494
# Epoch 17/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0462
# Epoch 18/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0434
# Epoch 19/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0410
# Epoch 20/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0388
# Epoch 21/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0369
# Epoch 22/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0352
# Epoch 23/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0337
# Epoch 24/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0323
# Epoch 25/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0310
# Epoch 26/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0298
# Epoch 27/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0287
# Epoch 28/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0277
# Epoch 29/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0268
# Epoch 30/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0259
# Epoch 31/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0251
# Epoch 32/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0243
# Epoch 33/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0236
# Epoch 34/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0229
# Epoch 35/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0223
# Epoch 36/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0216
# Epoch 37/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0211
# Epoch 38/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0205
# Epoch 39/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0199
# Epoch 40/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0194
# Epoch 41/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0189
# Epoch 42/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0184
# Epoch 43/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0179
# Epoch 44/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0175
# Epoch 45/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0171
# Epoch 46/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0166
# Epoch 47/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0162
# Epoch 48/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0158
# Epoch 49/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0155
# Epoch 50/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0151
# Epoch 51/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0147
# Epoch 52/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0144
# Epoch 53/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0141
# Epoch 54/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0137
# Epoch 55/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0134
# Epoch 56/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0131
# Epoch 57/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0128
# Epoch 58/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0125
# Epoch 59/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0122
# Epoch 60/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0120
# Epoch 61/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0117
# Epoch 62/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0115
# Epoch 63/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0112
# Epoch 64/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0110
# Epoch 65/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0107
# Epoch 66/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0105
# Epoch 67/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0103
# Epoch 68/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0101
# Epoch 69/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0099
# Epoch 70/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0097
# Epoch 71/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0095
# Epoch 72/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0093
# Epoch 73/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0091
# Epoch 74/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0089
# Epoch 75/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0087
# Epoch 76/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0086
# Epoch 77/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0084
# Epoch 78/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0082
# Epoch 79/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0081
# Epoch 80/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0079
# Epoch 81/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0078
# Epoch 82/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0077
# Epoch 83/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0075
# Epoch 84/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0074
# Epoch 85/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0073
# Epoch 86/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0071
# Epoch 87/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0070
# Epoch 88/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0069
# Epoch 89/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0068
# Epoch 90/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0067
# Epoch 91/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0066
# Epoch 92/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0065
# Epoch 93/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0064
# Epoch 94/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0063
# Epoch 95/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0062
# Epoch 96/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0061
# Epoch 97/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0061
# Epoch 98/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0060
# Epoch 99/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0059
# Epoch 100/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0058
# Epoch 101/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0058
# Epoch 102/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0057
# Epoch 103/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0056
# Epoch 104/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0056
# Epoch 105/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0055
# Epoch 106/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0054
# Epoch 107/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0054
# Epoch 108/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0053
# Epoch 109/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0053
# Epoch 110/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0052
# Epoch 111/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0052
# Epoch 112/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0051
# Epoch 113/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0051
# Epoch 114/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0050
# Epoch 115/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0050
# Epoch 116/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0049
# Epoch 117/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0049
# Epoch 118/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0049
# Epoch 119/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0048
# Epoch 120/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0048
# Epoch 121/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0047
# Epoch 122/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0047
# Epoch 123/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0047
# Epoch 124/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0046
# Epoch 125/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0046
# Epoch 126/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0046
# Epoch 127/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0045
# Epoch 128/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0045
# Epoch 129/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0045
# Epoch 130/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0044
# Epoch 131/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0044
# Epoch 132/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0044
# Epoch 133/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0044
# Epoch 134/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0043
# Epoch 135/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0043
# Epoch 136/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0043
# Epoch 137/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0043
# Epoch 138/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0042
# Epoch 139/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0042
# Epoch 140/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0042
# Epoch 141/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0041
# Epoch 142/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0041
# Epoch 143/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0041
# Epoch 144/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0041
# Epoch 145/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0041
# Epoch 146/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0040
# Epoch 147/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0040
# Epoch 148/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0040
# Epoch 149/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0040
# Epoch 150/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0040
# Epoch 151/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0039
# Epoch 152/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0039
# Epoch 153/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0039
# Epoch 154/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0039
# Epoch 155/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0039
# Epoch 156/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0038
# Epoch 157/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0038
# Epoch 158/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0038
# Epoch 159/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0038
# Epoch 160/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0038
# Epoch 161/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 162/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 163/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 164/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 165/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 166/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0037
# Epoch 167/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 168/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 169/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 170/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 171/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 172/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 173/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0036
# Epoch 174/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 175/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 176/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 177/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 178/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 179/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 180/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 181/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0035
# Epoch 182/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 183/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 184/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 185/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 186/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 187/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 188/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 189/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0034
# Epoch 190/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 191/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 192/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 193/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 194/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 195/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 196/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 197/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 198/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0033
# Epoch 199/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0032
# Epoch 200/200
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0032

# %%
pred = model(x_train[:10])
pred = 255*pred
pred = tf.image.convert_image_dtype(pred,dtype=tf.uint8)
label = tf.image.convert_image_dtype(x_train[:10]*255,dtype=tf.uint8)
# Out:
# WARNING:tensorflow:Layer conv2d_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
fig, axes = plt.subplots(10, 2, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
print(x_train.max())
x_train = x_train / 255.0
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_poisson(input_shape,activation="relu"):
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(1, kernel_size=(3, 3), padding="same") (layer)
    layer = Flatten()(layer)
    layer = Dense(28*28)(layer)
    layer = Activation(activation)(layer)
    layer = Dense(28*28)(layer)
    layer = tfp.layers.IndependentPoisson((28,28,1))(layer)
    
    model = Model(inputs=inputs, outputs=layer)
    return model
# Out:
# (60000, 28, 28)
# 255

# %%
model_poisson = test_ae_poisson([28,28,1])
model_poisson.compile(loss=NLL, optimizer=Adam( lr= 1e-3 ))
model_poisson.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# activation_9 (Activation)    (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_10 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_11 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_12 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 1)         289
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 784)               615440
# _________________________________________________________________
# activation_13 (Activation)   (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               615440
# _________________________________________________________________
# independent_poisson (Indepen ((None, 28, 28, 1), (None 0
# =================================================================
# Total params: 1,273,505
# Trainable params: 1,273,217
# Non-trainable params: 288
# _________________________________________________________________

# %%
model_poisson.fit(x_train,x_train,epochs=200,batch_size=300)
# Out:
# Train on 60000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 3s 44us/sample - loss: 178.4455
# Epoch 2/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 138.3367
# Epoch 3/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 133.6525
# Epoch 4/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 131.3146
# Epoch 5/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 129.7336
# Epoch 6/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 128.5898
# Epoch 7/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 127.6992
# Epoch 8/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 127.1406
# Epoch 9/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 126.3216
# Epoch 10/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 125.8290
# Epoch 11/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 125.3880
# Epoch 12/200
# 60000/60000 [==============================] - 2s 32us/sample - loss: 119.0594
# Epoch 196/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 119.0385
# Epoch 197/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 119.0556
# Epoch 198/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 119.0347
# Epoch 199/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 119.0208
# Epoch 200/200
# 60000/60000 [==============================] - 2s 31us/sample - loss: 119.0251

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
x_train = x_train 
x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_train = x_train / 255.0


#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)
pred = model_poisson(x_train[:10]).stddev()
#pred = tf.image.convert_image_dtype(pred,dtype=tf.uint8)
#label = tf.image.convert_image_dtype(x_train[:10],dtype=tf.uint8)
# Out:
# (60000, 28, 28)

# %%
fig, axes = plt.subplots(10, 2, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
print(x_train.max())
x_train = x_train / 255.0
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_poisson_zf(input_shape,activation="relu"):
    def zeroInflatedPoisson(output):
        rate = tf.math.exp(output[:,:,:,0:1]) #A 
        s = tf.math.sigmoid(output[:,:,:,1:2])
        
        pos = tfp.distributions.Poisson(rate=rate)
        det = tfp.distributions.Deterministic(loc=tf.zeros_like(rate))
        components = [det,pos]
        mixture = tfd.Mixture(
              cat=tfd.Categorical(probs=tf.stack([1-s, s],axis=-1)),#D
              components=components)
        return tfp.distributions.Independent(mixture,reinterpreted_batch_ndims=1,name="ZeroInflated")
    
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(2, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    #layer = Flatten()(layer)
    layer = tfp.layers.DistributionLambda(zeroInflatedPoisson,name="ZPoisson")(layer)
    
    model = Model(inputs=inputs, outputs=layer)
    return model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2eb55bdddc1a> in <module>
# ----> 1 (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
#       2 print(x_train.shape)
#       3 print(x_train.max())
#       4 x_train = x_train / 255.0
#       5 x_train = x_train.reshape(x_train.shape[0],28,28,1)
#
# NameError: name 'tf' is not defined

# %%
model_poisson_zf = test_ae_poisson_zf([28,28,1])
model_poisson_zf.compile(loss=NLL, optimizer=Adam( lr= 1e-5 ))
model_poisson_zf.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-171c905818b8> in <module>
# ----> 1 model_poisson_zf = test_ae_poisson_zf([28,28,1])
#       2 model_poisson_zf.compile(loss=NLL, optimizer=Adam( lr= 1e-5 ))
#       3 model_poisson_zf.summary()
#
# <ipython-input-4-eb985f947e29> in test_ae_poisson_zf(input_shape, activation)
#      48     layer = Activation(activation)(layer)
#      49     layer = Flatten()(layer)
# ---> 50     layer = tfp.layers.DistributionLambda(zeroInflatedPoisson,name="ZPoisson")(layer)
#      51
#      52     model = Model(inputs=inputs, outputs=layer)
#
# ~/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_probability/python/layers/distribution_layer.py in __call__(self, inputs, *args, **kwargs)
#     205     self._enter_dunder_call = True
#     206     distribution, _ = super(DistributionLambda, self).__call__(
# --> 207         inputs, *args, **kwargs)
#     208     self._enter_dunder_call = False
#     209     return distribution
#
# ~/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     771                     not base_layer_utils.is_in_eager_or_tf_function()):
#     772                   with auto_control_deps.AutomaticControlDependencies() as acd:
# --> 773                     outputs = call_fn(cast_inputs, *args, **kwargs)
#     774                     # Wrap Tensors in `outputs` in `tf.identity` to avoid
#     775                     # circular dependencies.
#
# ~/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     235       except Exception as e:  # pylint:disable=broad-except
#     236         if hasattr(e, 'ag_error_metadata'):
# --> 237           raise e.ag_error_metadata.to_exception(e)
#     238         else:
#     239           raise
#
# ValueError: in converted code:
#
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_probability/python/layers/distribution_layer.py:213 call
#         inputs, *args, **kwargs)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/core.py:846 call
#         result = self.function(inputs, **kwargs)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_probability/python/layers/distribution_layer.py:161 _fn
#         d = make_distribution_fn(*fargs, **fkwargs)
#     <ipython-input-4-eb985f947e29>:14 zeroInflatedPoisson
#         rate = tf.math.exp(output[:,:,:,0:1]) #A
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:898 _slice_helper
#         name=name)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1064 strided_slice
#         shrink_axis_mask=shrink_axis_mask)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_array_ops.py:9535 strided_slice
#         shrink_axis_mask=shrink_axis_mask, name=name)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/framework/op_def_library.py:742 _apply_op_helper
#         attrs=attr_protos, op_def=op_def)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/framework/func_graph.py:595 _create_op_internal
#         compute_device)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py:3322 _create_op_internal
#         op_def=op_def)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py:1786 __init__
#         control_input_ops)
#     /home_ext/ios/anaconda3/envs/DeepRain/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py:1622 _create_c_op
#         raise ValueError(str(e))
#
#     ValueError: Index out of range using input dim 2; input has only 2 dims for 'ZPoisson/strided_slice' (op: 'StridedSlice') with input shapes: [?,1568], [4], [4], [4] and with computed input tensors: input[3] = <1 1 1 1>.

# %%
model_poisson_zf.fit(x_train,x_train,epochs=100,batch_size=100)
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.7323
# Epoch 2/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6331
# Epoch 3/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5995
# Epoch 4/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.5762
# Epoch 5/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.5608
# Epoch 6/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.5476
# Epoch 7/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.5329
# Epoch 8/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.5231
# Epoch 9/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.5180
# Epoch 10/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.5358
# Epoch 11/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 12/100
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6219
# Epoch 13/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 14/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 15/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 16/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 17/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 18/100
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.6219
# Epoch 19/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 20/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 21/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 22/100
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6219
# Epoch 23/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 24/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 25/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 26/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 27/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 28/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 29/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 30/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 31/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 32/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 33/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 34/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 35/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 36/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 37/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 38/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 39/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 40/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 41/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 42/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 43/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 44/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 45/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 46/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 47/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 48/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 49/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 50/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 51/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 52/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 53/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 54/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 55/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 56/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 57/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 58/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 59/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 60/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 61/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 62/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 63/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 64/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 65/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 66/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 67/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 68/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 69/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 70/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 71/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 72/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 73/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 74/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 75/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 76/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 77/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 78/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 79/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 80/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 81/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 82/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 83/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 84/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 85/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 86/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 87/100
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.6219
# Epoch 88/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 89/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 90/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 91/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 92/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 93/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 94/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 95/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 96/100
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.6219
# Epoch 97/100
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6219
# Epoch 98/100
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6219
# Epoch 99/100
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6219
# Epoch 100/100
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6219

# %%
pred = model_poisson_zf(x_train[:10])

fig, axes = plt.subplots(10, 2, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype('int32')
x_train = x_train /255.0
x_train = x_train - 0.5


x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

print(x_train.min(),x_train.max())
def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_Normal(input_shape,activation="relu"):
 
    
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(2, kernel_size=(3, 3), padding="same") (layer)
    layer = Flatten()(layer)
    layer = Dense(28*28*2)(layer)
    layer = Activation(activation)(layer)
    layer = Dense(28*28*2)(layer)
    
    #layer = Flatten()(layer)
    #layer = Conv2D((tfpl.IndependentNormal.params_size(2)),kernel_size=(3,3),padding="same")  (layer)
    layer = tfp.layers.IndependentNormal((28,28,1))(layer)
    
    model = Model(inputs=inputs, outputs=layer)

    return model
# Out:
# -0.5 0.5

# %%
model_normal = test_ae_Normal([28,28,1])
model_normal.compile(loss=NLL, optimizer=Adam( lr= 1e-7 ))
model_normal.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# activation_44 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_45 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_46 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d_18 (UpSampling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_47 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_19 (UpSampling (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 28, 28, 2)         578
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1568)              2460192
# _________________________________________________________________
# activation_48 (Activation)   (None, 1568)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1568)              2460192
# _________________________________________________________________
# independent_normal_6 (Indepe ((None, 28, 28, 1), (None 0
# =================================================================
# Total params: 4,963,298
# Trainable params: 4,963,010
# Non-trainable params: 288
# _________________________________________________________________

# %%
model_normal.fit(x_train,x_train,epochs=18)
# Out:
# Train on 60000 samples
# Epoch 1/18
# 60000/60000 [==============================] - 8s 136us/sample - loss: 3876.4997
# Epoch 2/18
# 60000/60000 [==============================] - 8s 128us/sample - loss: 3676.7376
# Epoch 3/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 3493.8224
# Epoch 4/18
# 60000/60000 [==============================] - 8s 126us/sample - loss: 3327.6998
# Epoch 5/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 3179.0342
# Epoch 6/18
# 60000/60000 [==============================] - 8s 126us/sample - loss: 3035.3828
# Epoch 7/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 2903.0240
# Epoch 8/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 2782.2615
# Epoch 9/18
# 60000/60000 [==============================] - 8s 129us/sample - loss: 2668.2614
# Epoch 10/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 2561.5641
# Epoch 11/18
# 60000/60000 [==============================] - 8s 127us/sample - loss: 2465.5630
# Epoch 12/18
# 60000/60000 [==============================] - 8s 129us/sample - loss: 2371.6685
# Epoch 13/18
# 60000/60000 [==============================] - 8s 132us/sample - loss: 2286.2555
# Epoch 14/18
# 60000/60000 [==============================] - 8s 128us/sample - loss: 2206.7257
# Epoch 15/18
# 43328/60000 [====================>.........] - ETA: 2s - loss: 2138.5251

# %%
pred = model_normal(x_train[:10]).mean()
label = x_train[:10]
fig, axes = plt.subplots(10, 2, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred):
    axes[batch,0].imshow((img[:,:,0] + 0.5)*255 ,cmap="gray")
    axes[batch,1].imshow((label[batch,:,:,0] + 0.5) *255,cmap="gray")
