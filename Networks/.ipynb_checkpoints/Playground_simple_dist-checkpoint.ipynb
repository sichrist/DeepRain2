# %%
from Utils.loadset import getDataSet
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np


tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions
import os
from trainer import Trainer
try:
    from Utils.connection_cfg import *
except Exception as e:
    PSWD = None
    USRN = None
    
from Utils.Data import dataWrapper
from Utils.transform import ToCategorical, cutOut
# Out:
# Num GPUs Available: 1
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)
#y_test = y_test.reshape(y_train.shape[0],28,28,1)

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# (60000, 28, 28)

# %%
def test_ae(input_shape,activation="relu"):
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer = Conv2D(1, kernel_size=(3, 3), padding="same") (layer)
    
    model = Model(inputs=inputs, outputs=layer)
    return model

# %%
print(x_train.shape)
model = test_ae([28,28,1])
model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=Adam( lr= 1e-5 ))
model.summary()
# Out:
# (60000, 28, 28, 1)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 52,001
# Trainable params: 51,649
# Non-trainable params: 352
# _________________________________________________________________

# %%
model.fit(x_train,x_train,epochs=200,batch_size=400)
# Out:
# Epoch 1/200
# 150/150 [==============================] - 2s 15ms/step - loss: 1.3806
# Epoch 2/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.6827
# Epoch 3/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.4079
# Epoch 4/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2779
# Epoch 5/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.2041
# Epoch 6/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1575
# Epoch 7/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1263
# Epoch 8/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.1045
# Epoch 9/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0887
# Epoch 10/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0769
# Epoch 11/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0679
# Epoch 12/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0608
# Epoch 13/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0552
# Epoch 14/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0506
# Epoch 15/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0468
# Epoch 16/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0436
# Epoch 17/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0409
# Epoch 18/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0386
# Epoch 19/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0366
# Epoch 20/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0348
# Epoch 21/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0332
# Epoch 22/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0317
# Epoch 23/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0304
# Epoch 24/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0292
# Epoch 25/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0281
# Epoch 26/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0271
# Epoch 27/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0262
# Epoch 28/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0253
# Epoch 29/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0245
# Epoch 30/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0237
# Epoch 31/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0230
# Epoch 32/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0223
# Epoch 33/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0217
# Epoch 34/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0210
# Epoch 35/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0205
# Epoch 36/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0199
# Epoch 37/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0194
# Epoch 38/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0189
# Epoch 39/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0184
# Epoch 40/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0179
# Epoch 41/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0174
# Epoch 42/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0170
# Epoch 43/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0166
# Epoch 44/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0161
# Epoch 45/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0157
# Epoch 46/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0153
# Epoch 47/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0150
# Epoch 48/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0146
# Epoch 49/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0142
# Epoch 50/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0139
# Epoch 51/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0135
# Epoch 52/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0132
# Epoch 53/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0129
# Epoch 54/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0126
# Epoch 55/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0123
# Epoch 56/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0120
# Epoch 57/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0117
# Epoch 58/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0114
# Epoch 59/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0112
# Epoch 60/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0109
# Epoch 61/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0107
# Epoch 62/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0104
# Epoch 63/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0102
# Epoch 64/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0100
# Epoch 65/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0097
# Epoch 66/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0095
# Epoch 67/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0093
# Epoch 68/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0091
# Epoch 69/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0089
# Epoch 70/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0087
# Epoch 71/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0086
# Epoch 72/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0084
# Epoch 73/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0082
# Epoch 74/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0080
# Epoch 75/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0079
# Epoch 76/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0077
# Epoch 77/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0076
# Epoch 78/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0074
# Epoch 79/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0073
# Epoch 80/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0072
# Epoch 81/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0070
# Epoch 82/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0069
# Epoch 83/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0068
# Epoch 84/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0067
# Epoch 85/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0066
# Epoch 86/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0064
# Epoch 87/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0063
# Epoch 88/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0062
# Epoch 89/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0061
# Epoch 90/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0060
# Epoch 91/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0060
# Epoch 92/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0059
# Epoch 93/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0058
# Epoch 94/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0057
# Epoch 95/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0056
# Epoch 96/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0055
# Epoch 97/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0055
# Epoch 98/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0054
# Epoch 99/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0053
# Epoch 100/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0053
# Epoch 101/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0052
# Epoch 102/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0051
# Epoch 103/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0051
# Epoch 104/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0050
# Epoch 105/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0049
# Epoch 106/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0049
# Epoch 107/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0048
# Epoch 108/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0048
# Epoch 109/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0047
# Epoch 110/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0047
# Epoch 111/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0046
# Epoch 112/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0046
# Epoch 113/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0045
# Epoch 114/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0045
# Epoch 115/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0044
# Epoch 116/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0044
# Epoch 117/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0043
# Epoch 118/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0043
# Epoch 119/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0043
# Epoch 120/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0042
# Epoch 121/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0042
# Epoch 122/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0041
# Epoch 123/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0041
# Epoch 124/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0041
# Epoch 125/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0040
# Epoch 126/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0040
# Epoch 127/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0040
# Epoch 128/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0039
# Epoch 129/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0039
# Epoch 130/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0039
# Epoch 131/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0038
# Epoch 132/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0038
# Epoch 133/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0038
# Epoch 134/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0037
# Epoch 135/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0037
# Epoch 136/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0037
# Epoch 137/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0037
# Epoch 138/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0036
# Epoch 139/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0036
# Epoch 140/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0036
# Epoch 141/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0036
# Epoch 142/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0035
# Epoch 143/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0035
# Epoch 144/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0035
# Epoch 145/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0035
# Epoch 146/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0034
# Epoch 147/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0034
# Epoch 148/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0034
# Epoch 149/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0034
# Epoch 150/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0034
# Epoch 151/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0033
# Epoch 152/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0033
# Epoch 153/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0033
# Epoch 154/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0033
# Epoch 155/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0033
# Epoch 156/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 157/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 158/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 159/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 160/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 161/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0032
# Epoch 162/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 163/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 164/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 165/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 166/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 167/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0031
# Epoch 168/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 169/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 170/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 171/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 172/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 173/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 174/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0030
# Epoch 175/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 176/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 177/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 178/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 179/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 180/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 181/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 182/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0029
# Epoch 183/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0029
# Epoch 184/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 185/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 186/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 187/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 188/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 189/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0028
# Epoch 190/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 191/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0028
# Epoch 192/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0028
# Epoch 193/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 194/200
# 150/150 [==============================] - 2s 16ms/step - loss: 0.0027
# Epoch 195/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 196/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 197/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 198/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 199/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027
# Epoch 200/200
# 150/150 [==============================] - 2s 15ms/step - loss: 0.0027

# %%
pred = model(x_train[:10])
pred = 255*pred
pred = tf.image.convert_image_dtype(pred,dtype=tf.uint8)
label = tf.image.convert_image_dtype(x_train[:10]*255,dtype=tf.uint8)

# %%
fig, axes = plt.subplots(10, 2, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
print(x_train.max())
x_train = x_train / 255.0
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test / 255.0
x_test = x_test.reshape(x_test.shape[0],28,28,1)

def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_poisson(input_shape,activation="relu"):
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(1, kernel_size=(3, 3), padding="same") (layer)
    
    output = Flatten()(layer)
    output = Dense(16*16)(output)
    output = Dropout(0.1)(output)
    output = Dense(28*28,activation=tf.math.softmax)(output)
    rate = tf.keras.layers.Reshape((28,28,1))(output)
    
    #output = tfp.layers.IndependentPoisson((64,64,1))(output)
    output_dist = tfp.layers.DistributionLambda(
    make_distribution_fn=lambda t: tfp.distributions.Poisson(
            rate=t),
            #reinterpreted_batch_ndims=3
    )
    output = output_dist(rate)
    
    """
    layer = Flatten()(layer)
    layer = Dense(28*28)(layer)
    layer = Activation(activation)(layer)
    layer = Dense(28*28)(layer)
    layer = tfp.layers.IndependentPoisson((28,28,1))(layer)
    """
    
    
    model = Model(inputs=inputs, outputs=output)
    return model
# Out:
# (60000, 28, 28)
# 255

# %%
model_poisson = test_ae_poisson([28,28,1])
model_poisson.compile(loss=NLL, optimizer=Adam( lr= 2e-3 ))
model_poisson.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# activation_45 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_46 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_47 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d_18 (UpSampling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_48 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_19 (UpSampling (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 28, 28, 1)         289
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 784)               615440
# _________________________________________________________________
# activation_49 (Activation)   (None, 784)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 784)               615440
# _________________________________________________________________
# independent_poisson_5 (Indep ((None, 28, 28, 1), (None 0
# =================================================================
# Total params: 1,273,505
# Trainable params: 1,273,217
# Non-trainable params: 288
# _________________________________________________________________

# %%
model_poisson.fit( x_train,x_train,epochs=100,batch_size=400,validation_data=(x_test,x_test))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 2s 12ms/step - loss: 176.1073 - val_loss: 220.2349
# Epoch 2/100
# 150/150 [==============================] - 2s 12ms/step - loss: 137.7932 - val_loss: 170.2744
# Epoch 3/100
# 150/150 [==============================] - 2s 12ms/step - loss: 133.2553 - val_loss: 139.0180
# Epoch 4/100
# 150/150 [==============================] - 2s 12ms/step - loss: 130.9101 - val_loss: 133.3024
# Epoch 5/100
# 150/150 [==============================] - 2s 11ms/step - loss: 129.4328 - val_loss: 130.1011
# Epoch 6/100
# 150/150 [==============================] - 2s 12ms/step - loss: 128.2414 - val_loss: 129.6481
# Epoch 7/100
# 150/150 [==============================] - 2s 12ms/step - loss: 127.3947 - val_loss: 128.3833
# Epoch 8/100
# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
x_train = x_train 
x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_train = x_train / 255.0
x_test = x_test.reshape(x_test.shape[0],28,28,1)
x_test = x_test / 255.0
testset = x_test

label = tf.image.convert_image_dtype(testset[:10]*255,dtype=tf.uint8)

pred_mean = model_poisson(testset[:10]).mean()
pred_stddev = model_poisson(testset[:10]).stddev()
# Out:
# (60000, 28, 28)

# %%
fig, axes = plt.subplots(10, 3, figsize=(6,20),dpi=64)

for batch,img in enumerate(pred_mean):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,2].imshow(label[batch,:,:,0],cmap="gray")
    axes[batch,1].imshow(pred_stddev[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)
print(x_train.max())
x_train = x_train / 255.0
x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_poisson_zf(input_shape,activation="relu"):
    def zeroInflatedPoisson(output):
        rate = tf.math.exp(output[:,:,:,0:1]) #A 
        s = tf.math.sigmoid(output[:,:,:,1:2])
        
        pos = tfp.distributions.Poisson(rate=rate)
        det = tfp.distributions.Deterministic(loc=tf.zeros_like(rate))
        components = [det,pos]
        mixture = tfd.Mixture(
              cat=tfd.Categorical(probs=tf.stack([1-s, s],axis=-1)),#D
              components=components)
        return tfp.distributions.Independent(mixture,reinterpreted_batch_ndims=1,name="ZeroInflated")
    
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    #layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    #layer = Activation(activation)(layer)
    #layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    #layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(2, kernel_size=(3, 3), padding="same",activation="tanh") (layer)
    #layer = Activation(activation)(layer)
    layer_1 = Flatten()(layer[:,:,:,:1])
    layer_2 = Flatten()(layer[:,:,:,1:2])
    layer_1 = Dense(28*28,activation="tanh")(layer_1)
    layer_2 = Dense(28*28,activation="tanh")(layer_2)
    
    layer_stacked = tf.stack([layer_1,layer_2],axis=-1)
    layer = tf.reshape(layer_stacked, tf.shape(layer))
    layer = tfp.layers.DistributionLambda(zeroInflatedPoisson,name="ZPoisson")(layer)
    
    model = Model(inputs=inputs, outputs=layer)
    return model
# Out:
# (60000, 28, 28)
# 255

# %%
model_poisson_zf = test_ae_poisson_zf([28,28,1])
model_poisson_zf.compile(loss=NLL, optimizer=Adam( lr= 1e-5 ))
model_poisson_zf.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 28, 28, 16)   160         input_19[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 28, 28, 16)   0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 28, 28, 16)   64          activation_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 14, 14, 16)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 14, 14, 32)   4640        max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 14, 14, 32)   0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 14, 14, 32)   128         activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 14, 14, 32)   9248        batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 14, 14, 32)   0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 14, 14, 32)   128         activation_85[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_32 (UpSampling2D) (None, 28, 28, 32)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 28, 28, 2)    578         up_sampling2d_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_30 (T [(None, 28, 28, 1)]  0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_31 (T [(None, 28, 28, 1)]  0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# flatten_33 (Flatten)            (None, 784)          0           tf_op_layer_strided_slice_30[0][0
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 784)          0           tf_op_layer_strided_slice_31[0][0
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 784)          615440      flatten_33[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 784)          615440      flatten_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_15 (TensorFlo [(None, 784, 2)]     0           dense_31[0][0]
#                                                                  dense_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_9 (TensorFlow [(4,)]               0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_13 (TensorF [(None, 28, 28, 2)]  0           tf_op_layer_stack_15[0][0]
#                                                                  tf_op_layer_Shape_9[0][0]
# __________________________________________________________________________________________________
# ZPoisson (DistributionLambda)   ((None, 28, 28, 1),  0           tf_op_layer_Reshape_13[0][0]
# ==================================================================================================
# Total params: 1,245,826
# Trainable params: 1,245,666
# Non-trainable params: 160
# __________________________________________________________________________________________________

# %%
model_poisson_zf.fit(x_train,x_train,epochs=100,batch_size=100)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4685
# Epoch 2/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3676
# Epoch 3/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3571
# Epoch 4/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3508
# Epoch 5/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3458
# Epoch 6/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3416
# Epoch 7/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3380
# Epoch 8/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3348
# Epoch 9/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3318
# Epoch 10/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3292
# Epoch 11/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3269
# Epoch 12/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3248
# Epoch 13/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3229
# Epoch 14/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3212
# Epoch 15/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3196
# Epoch 16/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3181
# Epoch 17/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3168
# Epoch 18/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3157
# Epoch 19/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3146
# Epoch 20/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3136
# Epoch 21/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3127
# Epoch 22/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3119
# Epoch 23/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3111
# Epoch 24/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3104
# Epoch 25/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3097
# Epoch 26/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3091
# Epoch 27/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3086
# Epoch 28/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3080
# Epoch 29/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3075
# Epoch 30/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3070
# Epoch 31/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3066
# Epoch 32/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3061
# Epoch 33/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3057
# Epoch 34/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3053
# Epoch 35/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3050
# Epoch 36/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3046
# Epoch 37/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3043
# Epoch 38/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3040
# Epoch 39/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3037
# Epoch 40/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3034
# Epoch 41/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3031
# Epoch 42/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3028
# Epoch 43/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3026
# Epoch 44/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3023
# Epoch 45/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3021
# Epoch 46/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3019
# Epoch 47/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3016
# Epoch 48/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3014
# Epoch 49/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3012
# Epoch 50/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3010
# Epoch 51/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3008
# Epoch 52/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.3006
# Epoch 53/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3005
# Epoch 54/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3003
# Epoch 55/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3001
# Epoch 56/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3000
# Epoch 57/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2998
# Epoch 58/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2996
# Epoch 59/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2995
# Epoch 60/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2994
# Epoch 61/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2992
# Epoch 62/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2991
# Epoch 63/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2989
# Epoch 64/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2988
# Epoch 65/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2987
# Epoch 66/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2986
# Epoch 67/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2984
# Epoch 68/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2983
# Epoch 69/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2982
# Epoch 70/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2981
# Epoch 71/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2980
# Epoch 72/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2979
# Epoch 73/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2977
# Epoch 74/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2977
# Epoch 75/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2975
# Epoch 76/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2974
# Epoch 77/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2974
# Epoch 78/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2973
# Epoch 79/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2972
# Epoch 80/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2971
# Epoch 81/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2970
# Epoch 82/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2969
# Epoch 83/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2968
# Epoch 84/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2967
# Epoch 85/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2966
# Epoch 86/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2966
# Epoch 87/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2965
# Epoch 88/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2964
# Epoch 89/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2963
# Epoch 90/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2962
# Epoch 91/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2962
# Epoch 92/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2961
# Epoch 93/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2960
# Epoch 94/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2959
# Epoch 95/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2959
# Epoch 96/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2958
# Epoch 97/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2957
# Epoch 98/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2957
# Epoch 99/100
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2956
# Epoch 100/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2955

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

pred = model_poisson_zf(x_test[:10])
mean = pred.mean()
stddev = pred.stddev()
label = x_test[:10]

fig, axes = plt.subplots(10, 3, figsize=(6,20),dpi=64)

for batch,img in enumerate(mean):
    axes[batch,0].imshow(img[:,:,0],cmap="gray")
    axes[batch,1].imshow(stddev[batch,:,:,0],cmap="gray")
    axes[batch,2].imshow(label[batch,:,:,0],cmap="gray")

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype('int32')
x_train = x_train /255.0
x_train = x_train - 0.5


x_train = x_train.reshape(x_train.shape[0],28,28,1)
#y_train = y_train.reshape(y_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

print(x_train.min(),x_train.max())
def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)

def test_ae_Normal(input_shape,activation="relu"):
 
    
    inputs = Input(shape=input_shape)
    layer = Conv2D(16, kernel_size=(3, 3), padding="same") (inputs)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    layer  = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = Conv2D(64, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    #layer = MaxPooling2D((2, 2), strides=(2, 2))(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(32, kernel_size=(3, 3), padding="same") (layer)
    layer = Activation(activation)(layer)
    layer = BatchNormalization()(layer)
    
    layer = UpSampling2D((2, 2))(layer)
    layer = Conv2D(2, kernel_size=(3, 3), padding="same",activation="sigmoid") (layer)
    layer = Flatten()(layer)
    layer = Dense(28*28*2,activation="linear")(layer)
    #layer = Activation(activation)(layer)
    #layer = Dense(28*28*2)(layer)
    
    #layer = Flatten()(layer)
    #layer = Conv2D((tfpl.IndependentNormal.params_size(2)),kernel_size=(3,3),padding="same")  (layer)
    layer = tfp.layers.IndependentNormal((28,28,1))(layer)
    #layer = tfp.layers.MultivariateNormalTriL((28,28,1))(layer)
    
    model = Model(inputs=inputs, outputs=layer)

    return model
# Out:
# -0.5 0.5

# %%
model_normal = test_ae_Normal([28,28,1])
model_normal.compile(loss=lambda y, model_normal: -model_normal.log_prob(y), optimizer=Adam( lr= 1e-3 ),metrics = ["mse","mae"])
model_normal.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# activation_48 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_49 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_50 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# up_sampling2d_24 (UpSampling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# activation_51 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_25 (UpSampling (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 28, 28, 2)         578
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1568)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1568)              2460192
# _________________________________________________________________
# independent_normal_6 (Indepe ((None, 28, 28, 1), (None 0
# =================================================================
# Total params: 2,503,106
# Trainable params: 2,502,818
# Non-trainable params: 288
# _________________________________________________________________

# %%
model_normal.fit(x_train,x_train,epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -1082.0870 - mse: 0.1168 - mae: 0.1700
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -1664.1187 - mse: 0.0812 - mae: 0.1227
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -1894.8513 - mse: 0.0785 - mae: 0.1065
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2038.7533 - mse: 0.0738 - mae: 0.0935
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2140.4285 - mse: 0.0733 - mae: 0.0855
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2230.3818 - mse: 0.0716 - mae: 0.0795
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2299.3176 - mse: 0.0694 - mae: 0.0747
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2354.6260 - mse: 0.0689 - mae: 0.0715
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2408.2764 - mse: 0.0672 - mae: 0.0683
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -2440.8613 - mse: 0.0674 - mae: 0.0663
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3218.7053 - mse: 0.0388 - mae: 0.0359
# Epoch 62/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3225.6643 - mse: 0.0401 - mae: 0.0358
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3232.4395 - mse: 0.0392 - mae: 0.0355
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3236.9846 - mse: 0.0402 - mae: 0.0354
# Epoch 65/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3238.4978 - mse: 0.0400 - mae: 0.0354
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3247.7068 - mse: 0.0395 - mae: 0.0352
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3251.2637 - mse: 0.0392 - mae: 0.0350
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3261.3157 - mse: 0.0392 - mae: 0.0348
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3266.6726 - mse: 0.0393 - mae: 0.0345
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3275.3250 - mse: 0.0402 - mae: 0.0346
# Epoch 71/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3281.1624 - mse: 0.0385 - mae: 0.0342
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3287.0684 - mse: 0.0399 - mae: 0.0341
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3287.2400 - mse: 0.0391 - mae: 0.0341
# Epoch 74/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3292.7051 - mse: 0.0384 - mae: 0.0340
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3294.5278 - mse: 0.0387 - mae: 0.0340
# Epoch 76/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3300.9504 - mse: 0.0391 - mae: 0.0336
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3298.0967 - mse: 0.0388 - mae: 0.0337
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3310.3943 - mse: 0.0382 - mae: 0.0334
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3307.2554 - mse: 0.0386 - mae: 0.0333
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3307.8442 - mse: 0.0383 - mae: 0.0332
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3318.0168 - mse: 0.0392 - mae: 0.0330
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3324.7898 - mse: 0.0367 - mae: 0.0329
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3334.7581 - mse: 0.0368 - mae: 0.0327
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3339.3521 - mse: 0.0364 - mae: 0.0327
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3343.7979 - mse: 0.0372 - mae: 0.0326
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3348.3052 - mse: 0.0379 - mae: 0.0325
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3354.1206 - mse: 0.0363 - mae: 0.0324
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3359.2766 - mse: 0.0366 - mae: 0.0322
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3362.1033 - mse: 0.0364 - mae: 0.0322
# Epoch 90/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3371.5613 - mse: 0.0357 - mae: 0.0320
# Epoch 91/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3375.4084 - mse: 0.0364 - mae: 0.0320
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3378.5608 - mse: 0.0381 - mae: 0.0321
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3384.6936 - mse: 0.0365 - mae: 0.0320
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3383.6787 - mse: 0.0379 - mae: 0.0319
# Epoch 95/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3391.0061 - mse: 0.0361 - mae: 0.0318
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3393.3267 - mse: 0.0365 - mae: 0.0316
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3393.2544 - mse: 0.0363 - mae: 0.0316
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3401.4194 - mse: 0.0375 - mae: 0.0316
# Epoch 99/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3404.6045 - mse: 0.0363 - mae: 0.0314
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: -3401.1472 - mse: 0.0349 - mae: 0.0312

# %%
pred = model_normal(x_train[:10])
mean = pred.mean()
stddev = pred.stddev()
label = x_train[:10]
fig, axes = plt.subplots(10, 3, figsize=(6,20),dpi=64)

for batch,img in enumerate(mean):
    axes[batch,0].imshow((img[:,:,0] + 0.5)*255 ,cmap="gray")
    axes[batch,1].imshow((stddev[batch,:,:,0] + 0.5)*255 ,cmap="gray")
    axes[batch,2].imshow((label[batch,:,:,0] + 0.5) *255,cmap="gray")
