# %%
from Utils.loadset import getDataSet
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_probability as tfp
import os
physical_devices = tf.config.list_physical_devices('GPU') 
print("Num GPUs:", len(physical_devices)) 

from trainer import Trainer
try:
    from Utils.connection_cfg import *
except Exception as e:
    PSWD = None
    USRN = None
    
from Utils.Data import dataWrapper, provideData
from Utils.transform import cutOut


tfd = tfp.distributions
def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)
# Out:
# Num GPUs: 1
# Num GPUs Available: 1
# Using TensorFlow backend.

# %%
dimension = (128,128)
channels = 5

slices = [224,352,224,352]
slices_label = [32,64+32,32,64+32]
cutOutFrame = cutOut(slices)
cutOutFrame_label = cutOut(slices_label)
years = [2015,2016,2017]
PRETRAINING_TRANSFORMATIONS = [cutOutFrame]
TRANSFORMATION = [cutOutFrame_label]
batch_size = 5

train, test = provideData(dimension=dimension,
                          batch_size=batch_size,
                          channels = channels,
                          timeToPred = 5,
                          year = years,
                          transform=TRANSFORMATION,
                          preTransformation=PRETRAINING_TRANSFORMATIONS)
# Out:
# Found Year :  2015 => won't download this year again... please check for consistency
# Found Year :  2016 => won't download this year again... please check for consistency
# Found Year :  2017 => won't download this year again... please check for consistency
# Finished Loading Dataset
#
# [DEBUG] Data
# [DEBUG] time to predict:  5
# [DEBUG] Data
# [DEBUG] time to predict:  5

# %%
def negative_Binomial_Unet_128x128IN(input_shape,
                           activation_hidden="relu",
                           activation_output="relu"):


    inputs = Input(shape=input_shape) 

    conv01 = Conv2D(10, kernel_size=(3, 3), padding="same")(inputs)       # 10 x 64x64
    conv01 = Activation(activation_hidden)(conv01)
    conv01_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv01)            # 10 x 32x32


    conv02 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv01_pool)  # 20 x 32x32
    conv02 = Activation(activation_hidden)(conv02)
    conv02_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv02)            # 20 x 16x16


    conv03 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv02_pool)  # 20 x 16x16
    conv03 = Activation(activation_hidden)(conv03)
    conv03_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv03)            # 20 x 8x8


    conv04 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv03_pool)  # 20 x 8x8
    conv04 = Activation(activation_hidden)(conv04)
    conv04_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv04)            # 20 x 4x4


    ### UPSAMPLING:
    up04 = UpSampling2D((2, 2))(conv04_pool)    # 20 x 8x8
    up04 = concatenate([conv04, up04], axis=3)  # 20+20 x 8x8


    up03 = UpSampling2D((2, 2))(up04)           # 40 x 16x16
    up03 = concatenate([conv03, up03], axis=3)  # 20+40 x 16x16


    up02 = UpSampling2D((2, 2))(up03)           # 60 x 32x32
    up01 = concatenate([conv02, up02], axis=3)  # 20+60 x 32x32


    #up01 = UpSampling2D((2, 2))(up02)           # 80 x 64x64
    #up01 = concatenate([conv01, up01], axis=3)  # 10+80 x 64x64
    
    
    output = Conv2D(2, (1, 1), activation="relu")(up01)  # 1 x 64x64

    shape = tf.shape(output)
    shape = output.shape
    print(shape)
    
    max_count = output[:,:,:,:1]
    prob      = output[:,:,:,1:2]
    max_count = Flatten()(max_count)
    prob      = Flatten()(prob)
    prob      = Dense(16*16)(prob)
    prob      = Dropout(0.1)(prob)
    
    max_count      = Dense(64*64)(max_count)
    #max_count      = Dropout(0.1)(max_count)
    
    prob      = Dense(64*64,activation="sigmoid")(prob)
    max_count = Dense(64*64,activation="sigmoid")(max_count)
    prob      = tf.keras.layers.Reshape((64,64,1))(prob)
    max_count = tf.keras.layers.Reshape((64,64,1))(max_count)
    input_dist= tf.concat([tf.math.softplus(max_count),prob],axis=-1)
    
    #print(max_count)
    
    output_dist = tfp.layers.DistributionLambda(name="DistributionLayer",
        make_distribution_fn=lambda t: tfd.Independent(tfp.distributions.NegativeBinomial(
            total_count=t[..., :1], probs=t[..., 1:2] ),
                                                      reinterpreted_batch_ndims=-1 ))
            #,convert_to_tensor_fn=lambda s: s.sample(64,64,1))

    output = output_dist(input_dist)
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
optimizer = Adam( lr = 1e-3 )
trainer = Trainer(negative_Binomial_Unet_128x128IN,
                    lossfunction=NLL,
                    pathToData=(train,test),
                    batch_size = batch_size,
                    optimizer=optimizer,
                    dimension = dimension,
                    channels = channels,
                    metrics = ["mse","mae"])
layer_name="DistributionLayer"
print(trainer.model.get_layer(layer_name).output)
# Out:
# (None, 64, 64, 2)
# [Load file failed]  ./model_data/negative_Binomial_Unet_128x128IN_function/negative_Binomial_Unet_128x128IN_function128x128x5.h5
# [Load file failed]  ./model_data/negative_Binomial_Unet_128x128IN_function/negative_Binomial_Unet_128x128IN_function128x128x5history.json
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 5) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 10) 460         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 10) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 10)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 20)   1820        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 20)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 20)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 20)   3620        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 20)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 20)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 20)   3620        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 20)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 20)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 20)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 40)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 40)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 60)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 60)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 80)   0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 2)    162         concatenate_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 64, 64, 1)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 64, 64, 1)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          1048832     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4096)         16781312    dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64, 64, 1)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4096)         1052672     dropout[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softplus (TensorFlo [(None, 64, 64, 1)]  0           reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1)    0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 64, 64, 2)]  0           tf_op_layer_Softplus[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# DistributionLayer (Distribution ((None, 64, 64, 1),  0           tf_op_layer_concat[0][0]
# ==================================================================================================
# Total params: 35,673,810
# Trainable params: 35,673,810
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (<tfp.distributions.Independent 'DistributionLayer_IndependentDistributionLayer_NegativeBinomial' batch_shape=[?, 64, 64, 1] event_shape=[] dtype=float32>, <tf.Tensor 'DistributionLayer/Identity:0' shape=(None, 64, 64, 1) dtype=float32>)

# %%
trainer.fit(400)
# Out:
# Epoch 1/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.5574 - mse: 23.5589 - mae: 1.0172
# /home/simon/Dokumente/Teamprojekt/DeepRain2/Networks/Utils/transform.py:108: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return img[self.slices]
# Epoch 00001: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.
400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6354 - mse: 20.0058 - mae: 1.1504
# Epoch 00358: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6792 - mse: 18.8570 - mae: 1.1831 - val_loss: 1.6560 - val_mse: 1.3958 - val_mae: 0.2697
# Epoch 359/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6702 - mse: 18.3116 - mae: 1.1181
# Epoch 00359: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6355 - mse: 19.1390 - mae: 1.0876 - val_loss: 1.6674 - val_mse: 1.5292 - val_mae: 0.2914
# Epoch 360/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6261 - mse: 15.4536 - mae: 1.0304
# Epoch 00360: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6014 - mse: 16.2828 - mae: 1.0145 - val_loss: 1.6882 - val_mse: 1.4244 - val_mae: 0.2632
# Epoch 361/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6364 - mse: 18.2127 - mae: 1.0918
# Epoch 00361: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6564 - mse: 17.1749 - mae: 1.1035 - val_loss: 1.5564 - val_mse: 1.3308 - val_mae: 0.2561
# Epoch 362/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6645 - mse: 25.9406 - mae: 1.2350
# Epoch 00362: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6770 - mse: 22.2122 - mae: 1.1916 - val_loss: 1.5741 - val_mse: 1.4818 - val_mae: 0.2843
# Epoch 363/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7375 - mse: 25.5483 - mae: 1.3372
# Epoch 00363: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7157 - mse: 21.7160 - mae: 1.2476 - val_loss: 1.7260 - val_mse: 1.4566 - val_mae: 0.2771
# Epoch 364/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6646 - mse: 15.7616 - mae: 1.0805
# Epoch 00364: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6982 - mse: 18.2342 - mae: 1.1819 - val_loss: 1.8656 - val_mse: 1.4679 - val_mae: 0.2889
# Epoch 365/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6276 - mse: 16.9016 - mae: 1.0485
# Epoch 00365: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6064 - mse: 16.7349 - mae: 1.0102 - val_loss: 1.7069 - val_mse: 1.4575 - val_mae: 0.2781
# Epoch 366/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7391 - mse: 18.2161 - mae: 1.1985
# Epoch 00366: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7390 - mse: 18.1012 - mae: 1.1916 - val_loss: 1.6255 - val_mse: 1.3398 - val_mae: 0.2567
# Epoch 367/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7522 - mse: 19.9596 - mae: 1.2522
# Epoch 00367: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6256 - mse: 16.6652 - mae: 1.0389 - val_loss: 1.7470 - val_mse: 1.4151 - val_mae: 0.2699
# Epoch 368/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7549 - mse: 22.2126 - mae: 1.2769
# Epoch 00368: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7677 - mse: 22.4672 - mae: 1.3005 - val_loss: 1.5984 - val_mse: 1.3582 - val_mae: 0.2691
# Epoch 369/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7327 - mse: 15.0048 - mae: 1.1644
# Epoch 00369: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7098 - mse: 15.2046 - mae: 1.1490 - val_loss: 1.7949 - val_mse: 1.4340 - val_mae: 0.2715
# Epoch 370/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6510 - mse: 24.2646 - mae: 1.1948
# Epoch 00370: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6930 - mse: 21.4333 - mae: 1.2011 - val_loss: 1.7515 - val_mse: 1.4433 - val_mae: 0.2772
# Epoch 371/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.5624 - mse: 9.1262 - mae: 0.8260
# Epoch 00371: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5788 - mse: 11.7911 - mae: 0.9046 - val_loss: 1.5382 - val_mse: 1.2755 - val_mae: 0.2495
# Epoch 372/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7590 - mse: 28.7974 - mae: 1.3667
# Epoch 00372: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6822 - mse: 24.9578 - mae: 1.2296 - val_loss: 1.6539 - val_mse: 1.3721 - val_mae: 0.2601
# Epoch 373/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6386 - mse: 14.4446 - mae: 1.0093
# Epoch 00373: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6417 - mse: 20.1295 - mae: 1.1098 - val_loss: 1.4385 - val_mse: 1.3204 - val_mae: 0.2599
# Epoch 374/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6875 - mse: 25.7117 - mae: 1.2720
# Epoch 00374: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6656 - mse: 21.5262 - mae: 1.1766 - val_loss: 1.7073 - val_mse: 1.3149 - val_mae: 0.2558
# Epoch 375/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6536 - mse: 24.9885 - mae: 1.1203
# Epoch 00375: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6685 - mse: 23.6329 - mae: 1.1673 - val_loss: 1.6116 - val_mse: 1.5310 - val_mae: 0.2947
# Epoch 376/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6014 - mse: 15.7631 - mae: 1.0399
# Epoch 00376: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6458 - mse: 17.1245 - mae: 1.1163 - val_loss: 1.8466 - val_mse: 1.4872 - val_mae: 0.2850
# Epoch 377/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6349 - mse: 13.2577 - mae: 0.9776
# Epoch 00377: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6404 - mse: 15.4627 - mae: 1.0414 - val_loss: 1.7219 - val_mse: 1.3713 - val_mae: 0.2709
# Epoch 378/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6660 - mse: 20.7633 - mae: 1.1485
# Epoch 00378: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6717 - mse: 19.7328 - mae: 1.1383 - val_loss: 1.5818 - val_mse: 1.4439 - val_mae: 0.2779
# Epoch 379/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7292 - mse: 23.3222 - mae: 1.2744
# Epoch 00379: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7595 - mse: 21.3625 - mae: 1.2799 - val_loss: 1.5551 - val_mse: 1.4099 - val_mae: 0.2702
# Epoch 380/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6818 - mse: 15.5792 - mae: 1.1154
# Epoch 00380: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6284 - mse: 14.7943 - mae: 1.0350 - val_loss: 1.5258 - val_mse: 1.4875 - val_mae: 0.2799
# Epoch 381/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7462 - mse: 23.1223 - mae: 1.3358
# Epoch 00381: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6381 - mse: 18.7505 - mae: 1.1259 - val_loss: 1.8830 - val_mse: 1.4263 - val_mae: 0.2782
# Epoch 382/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6578 - mse: 16.8576 - mae: 1.0960
# Epoch 00382: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6620 - mse: 16.8172 - mae: 1.1100 - val_loss: 1.8279 - val_mse: 1.5847 - val_mae: 0.3003
# Epoch 383/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7884 - mse: 24.5779 - mae: 1.3871
# Epoch 00383: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7099 - mse: 23.7986 - mae: 1.2430 - val_loss: 1.6472 - val_mse: 1.4333 - val_mae: 0.2793
# Epoch 384/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7128 - mse: 20.3090 - mae: 1.2127
# Epoch 00384: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7104 - mse: 21.5092 - mae: 1.2204 - val_loss: 1.8434 - val_mse: 1.4520 - val_mae: 0.2825
# Epoch 385/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7361 - mse: 20.0602 - mae: 1.2537
# Epoch 00385: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6761 - mse: 18.1573 - mae: 1.1504 - val_loss: 1.6084 - val_mse: 1.4120 - val_mae: 0.2650
# Epoch 386/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7223 - mse: 22.3073 - mae: 1.2833
# Epoch 00386: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6813 - mse: 20.0376 - mae: 1.1819 - val_loss: 1.6332 - val_mse: 1.3557 - val_mae: 0.2586
# Epoch 387/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6779 - mse: 15.7911 - mae: 1.1199
# Epoch 00387: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7156 - mse: 16.7558 - mae: 1.2011 - val_loss: 1.6349 - val_mse: 1.4424 - val_mae: 0.2697
# Epoch 388/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7082 - mse: 17.9934 - mae: 1.1997
# Epoch 00388: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6302 - mse: 15.3927 - mae: 1.0494 - val_loss: 1.5886 - val_mse: 1.4581 - val_mae: 0.2703
# Epoch 389/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6113 - mse: 19.7766 - mae: 1.0847
# Epoch 00389: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6103 - mse: 18.9685 - mae: 1.0530 - val_loss: 1.6650 - val_mse: 1.4390 - val_mae: 0.2658
# Epoch 390/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6578 - mse: 19.6041 - mae: 1.1444
# Epoch 00390: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6844 - mse: 19.0021 - mae: 1.1513 - val_loss: 1.7772 - val_mse: 1.3697 - val_mae: 0.2627
# Epoch 391/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6982 - mse: 20.1876 - mae: 1.1975
# Epoch 00391: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6628 - mse: 17.9702 - mae: 1.1242 - val_loss: 1.6930 - val_mse: 1.4901 - val_mae: 0.2813
# Epoch 392/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7128 - mse: 19.1095 - mae: 1.1970
# Epoch 00392: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6853 - mse: 17.8648 - mae: 1.1401 - val_loss: 1.6102 - val_mse: 1.3431 - val_mae: 0.2535
# Epoch 393/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6187 - mse: 15.2258 - mae: 1.0145
# Epoch 00393: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6633 - mse: 18.9704 - mae: 1.1386 - val_loss: 1.6461 - val_mse: 1.3972 - val_mae: 0.2696
# Epoch 394/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8259 - mse: 19.0158 - mae: 1.3576
# Epoch 00394: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7259 - mse: 17.8320 - mae: 1.1979 - val_loss: 1.7064 - val_mse: 1.3508 - val_mae: 0.2626
# Epoch 395/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7434 - mse: 48.8156 - mae: 1.4919
# Epoch 00395: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7354 - mse: 40.0861 - mae: 1.3903 - val_loss: 1.6228 - val_mse: 1.3424 - val_mae: 0.2624
# Epoch 396/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6310 - mse: 22.9840 - mae: 1.1088
# Epoch 00396: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6660 - mse: 29.2426 - mae: 1.2680 - val_loss: 1.9237 - val_mse: 1.5668 - val_mae: 0.2930
# Epoch 397/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6944 - mse: 19.8702 - mae: 1.1840
# Epoch 00397: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6884 - mse: 17.6678 - mae: 1.1380 - val_loss: 1.4987 - val_mse: 1.3177 - val_mae: 0.2536
# Epoch 398/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7118 - mse: 27.6551 - mae: 1.3263
# Epoch 00398: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6536 - mse: 23.4839 - mae: 1.1909 - val_loss: 1.6605 - val_mse: 1.5421 - val_mae: 0.3002
# Epoch 399/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6596 - mse: 13.9635 - mae: 1.0887
# Epoch 00399: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7027 - mse: 23.7313 - mae: 1.2477 - val_loss: 1.6888 - val_mse: 1.3263 - val_mae: 0.2498
# Epoch 400/400
# 5/7 [====================>.........] - ETA: 0s - loss: 0.5995 - mse: 29.1954 - mae: 1.1287
# Epoch 00400: val_loss did not improve from 0.62052
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6351 - mse: 24.7971 - mae: 1.1373 - val_loss: 1.8711 - val_mse: 1.6278 - val_mae: 0.3104

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
history = trainer.history
def plotHistory():
    # Plot training & validation accuracy values
    plt.plot(history['mse'])
    plt.plot(history['val_mse'])
    plt.title('Model MSE')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
plotHistory()

# %%
model = trainer.model
pred = None
label = None
pred_ = 20
test.on_epoch_end()
mean = []
stdev = []
label = []
prediction = []
for x,y in train:
    for i in range(batch_size):
        if y[i,:,:,:].max() > 0:
            pred = model(np.array([x[i,:,:,:]]))
            prediction.append(pred)
            mean.append(pred.mean())
            stdev.append(pred.stddev())
            label.append(y[i,:,:,:])
    if len(label) >= pred_:
        break

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
fig, axes = plt.subplots(20, 3, figsize=(16,8*10),dpi=64)
#fig.set_title(["mean","stdev","label"])
for batch,img in enumerate(mean):
    if batch == 20:
        break
    axes[batch,0].imshow(stdev[batch][0,:,:,0],cmap="gray")
    axes[batch,1].imshow(img[0,:,:,0],cmap="gray")
    axes[batch,2].imshow(label[batch][:,:,0],cmap="gray")

# %%
def map_Dist_To_Rain(prediction,label):
    
    x,y,t      = prediction[0][0,:,:,:].shape
    rain_true  = np.zeros((x,y,t))
    rain_false = rain_true.copy()
    
    
    
    ones = np.ones((x,y))
    zeros = np.zeros((x,y,t))
    value_map = np.array([ones * i/255 for i in range(256)])
    value_map = value_map.transpose(1,2,0)
    for i,pred in enumerate(prediction):
        ones = np.ones((x,y,t)) * 3/255
        #print((np.array(pred.prob(ones))).max(axis=-1) )
        probs = np.array(pred.prob(value_map))
        print(label[i].max())
        max_probs = probs.argmax(axis=-1)
        #print(probs[0,1,1,:].argmax())

        #print(probs.argmax(axis=-1))
        #print(probs.max(axis=-1))
        for j in range(64):
            for k in range(64):
                at = np.argmax(probs[0,k,j,:])
                if at > 0:
                #at = probs[0,k,j,:] .sum()
                    print("AATT",at)
        #    print(j,"min:",probs[:,:,:,j].min(),"max:",probs[:,:,:,j].max())
        #print(probs.shape)
        #print(probs)
        #print(pred.prob(0.0))
        print(np.array(pred.prob(label[i].max())).max() )
        print(np.array(pred.prob(label[i].max())).min() )
        if label[i].max() == 0:
            continue

        print(pred)
        s = (1-pred.cdf(zeros))
        
        #print(np.array(s).max(),np.array(probs.mean()).max(),label[i].max())
        
        plt.imshow(max_probs[0,:,:],cmap="gray")
        plt.show()
        plt.imshow(s[0,:,:,0],cmap="gray")
        plt.show()
        plt.imshow(label[i][:,:,0],cmap="gray")
        plt.show()
        break
    

#map_Dist_To_Rain(prediction,label)
print(prediction[0])
# Out:
# tfp.distributions.Independent("model_DistributionLayer_Independentmodel_DistributionLayer_NegativeBinomial", batch_shape=[1, 64, 64, 1], event_shape=[], dtype=float32)

# %%
a = np.arange(20)
print(label[0].max())
idx = np.where(label[0] == label[0].max() )
pred = prediction[0]
for i in range(20):
    a = np.ones((64,64,1)) * i
    #print(i,np.array(pred.prob(a)).max() )
#print(np.array(pred.mean())[33,28])
y = []
x = []
for i in range(20):
    x.append(i)
    #print(i,np.array(pred.prob(i))[0,33,28,:] )
    y.append(np.array(pred.prob(i))[0,idx[0],idx[1],0][0])
print(np.array(pred.mean())[0,idx[0],idx[1],0][0])

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(200,8.27)})
sns.barplot(x,y)
# Out:
# 35
# 22.670967
