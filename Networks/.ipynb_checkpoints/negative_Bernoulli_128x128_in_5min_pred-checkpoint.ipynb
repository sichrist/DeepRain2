# %%
from Utils.loadset import getDataSet
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow_probability as tfp
import os
physical_devices = tf.config.list_physical_devices('GPU') 
print("Num GPUs:", len(physical_devices)) 

from trainer import Trainer
try:
    from Utils.connection_cfg import *
except Exception as e:
    PSWD = None
    USRN = None
    
from Utils.Data import dataWrapper, provideData
from Utils.transform import cutOut


tfd = tfp.distributions
def NLL(y_true, y_hat):
    return -y_hat.log_prob(y_true)
# Out:
# Num GPUs: 1
# Num GPUs Available: 1
# Using TensorFlow backend.

# %%
dimension = (128,128)
channels = 7

slices = [224,352,224,352]
slices_label = [32,64+32,32,64+32]
cutOutFrame = cutOut(slices)
cutOutFrame_label = cutOut(slices_label)
years = [2017]
PRETRAINING_TRANSFORMATIONS = [cutOutFrame]
TRANSFORMATION = [cutOutFrame_label]
batch_size = 200

train, test = provideData(dimension=dimension,
                          batch_size=batch_size,
                          channels = channels,
                          timeToPred = 30,
                          onlyUseYears=[2016],
                          transform=TRANSFORMATION,
                          preTransformation=PRETRAINING_TRANSFORMATIONS)
# Out:
# Found Year :  2017 => won't download this year again... please check for consistency
# Finished Loading Dataset
#
# [DEBUG] Data
# [DEBUG] time to predict:  30
# SORTTING OUUUT 38120
# [DEBUG] Data
# [DEBUG] time to predict:  30
# SORTTING OUUUT 8156

# %%
def negative_Binomial_Unet_128x128IN(input_shape,
                           activation_hidden="relu",
                           activation_output="relu"):


    inputs = Input(shape=input_shape) 

    conv01 = Conv2D(14, kernel_size=(3, 3), padding="same")(inputs)       # 10 x 64x64
    conv01 = Activation(activation_hidden)(conv01)
    conv01_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv01)            # 10 x 32x32


    conv02 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv01_pool)  # 20 x 32x32
    conv02 = Activation(activation_hidden)(conv02)
    conv02_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv02)            # 20 x 16x16


    conv03 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv02_pool)  # 20 x 16x16
    conv03 = Activation(activation_hidden)(conv03)
    conv03_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv03)            # 20 x 8x8


    conv04 = Conv2D(20, kernel_size=(3, 3), padding="same")(conv03_pool)  # 20 x 8x8
    conv04 = Activation(activation_hidden)(conv04)
    conv04_pool = MaxPooling2D((2, 2), strides=(2, 2))(conv04)            # 20 x 4x4


    ### UPSAMPLING:
    up04 = UpSampling2D((2, 2))(conv04_pool)    # 20 x 8x8
    up04 = concatenate([conv04, up04], axis=3)  # 20+20 x 8x8


    up03 = UpSampling2D((2, 2))(up04)           # 40 x 16x16
    up03 = concatenate([conv03, up03], axis=3)  # 20+40 x 16x16


    up02 = UpSampling2D((2, 2))(up03)           # 60 x 32x32
    up01 = concatenate([conv02, up02], axis=3)  # 20+60 x 32x32


    #up01 = UpSampling2D((2, 2))(up02)           # 80 x 64x64
    #up01 = concatenate([conv01, up01], axis=3)  # 10+80 x 64x64
    
    
    output = Conv2D(2, (1, 1), activation="relu")(up01)  # 1 x 64x64

    shape = tf.shape(output)
    shape = output.shape
 
    
    max_count = output[:,:,:,:1]
    prob      = output[:,:,:,1:2]
    max_count = Flatten()(max_count)
    prob      = Flatten()(prob)
    prob      = Dense(16*16)(prob)
    #prob      = Dropout(0.2)(prob)
    
    max_count      = Dense(64*64)(max_count)
    #max_count      = Dropout(0.2)(max_count)
    
    prob      = Dense(64*64,activation="sigmoid")(prob)
    max_count = Dense(64*64,activation="sigmoid")(max_count)
    prob      = tf.keras.layers.Reshape((64,64,1))(prob)
    max_count = tf.keras.layers.Reshape((64,64,1))(max_count)
    input_dist= tf.concat([max_count,prob],axis=-1)
    
    #print(max_count)
    
    output_dist = tfp.layers.DistributionLambda(name="DistributionLayer",
        make_distribution_fn=lambda t: tfd.Independent(tfp.distributions.NegativeBinomial(
            total_count=t[..., 1], probs=t[..., 1] ),
                                                      reinterpreted_batch_ndims=0 ))
            #,convert_to_tensor_fn=lambda s: s.sample(64,64,1))

    output = output_dist(input_dist)
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
optimizer = Adam( lr = 1e-4 )
trainer = Trainer(negative_Binomial_Unet_128x128IN,
                    lossfunction=NLL,
                    pathToData=(train,test),
                    batch_size = batch_size,
                    optimizer=optimizer,
                    dimension = dimension,
                    channels = channels,
                    metrics = ["mse","mae"])
layer_name="DistributionLayer"
print(trainer.model.get_layer(layer_name).output)
# Out:
# [Loaded file]  ./model_data/negative_Binomial_Unet_128x128IN_function/negative_Binomial_Unet_128x128IN_function128x128x7.h5
# 1100
# [Loaded file]  ./model_data/negative_Binomial_Unet_128x128IN_function/negative_Binomial_Unet_128x128IN_function128x128x7history.json
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 7) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 14) 896         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 14) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 14)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 20)   2540        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 20)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 20)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 20)   3620        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 20)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 20)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 20)   3620        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 20)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 20)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 20)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 40)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 40)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 60)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 60)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 80)   0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 2)    162         concatenate_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 64, 64, 1)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 64, 64, 1)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          1048832     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4096)         16781312    dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4096)         1052672     dense[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64, 64, 1)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1)    0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 64, 64, 2)]  0           reshape_1[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# DistributionLayer (Distribution ((None, 64, 64), (No 0           tf_op_layer_concat[0][0]
# ==================================================================================================
# Total params: 35,674,966
# Trainable params: 35,674,966
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (<tfp.distributions.Independent 'DistributionLayer_IndependentDistributionLayer_NegativeBinomial' batch_shape=[?, 64, 64] event_shape=[] dtype=float32>, <tf.Tensor 'DistributionLayer/Identity:0' shape=(None, 64, 64) dtype=float32>)

# %%
#trainer.fit(50)
# Out:
# /home/simon/Dokumente/Teamprojekt/DeepRain2/Networks/Utils/transform.py:120: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return img[self.slices]
# Epoch 1101/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.5971 - mse: 69.7594 - mae: 2.8635
# Epoch 01101: val_loss improved from inf to 1.39892, saving model to ./model_data/negative_Binomial_Unet_128x128IN_function/model-1101-1.597057-1.398919.h5
# 190/190 [==============================] - 87s 460ms/step - loss: 1.5971 - mse: 69.7594 - mae: 2.8635 - val_loss: 1.3989 - val_mse: 55.1097 - val_mae: 2.5538
# Epoch 1102/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6058 - mse: 70.9200 - mae: 2.8856
# Epoch 01102: val_loss improved from 1.39892 to 1.38151, saving model to ./model_data/negative_Binomial_Unet_128x128IN_function/model-1102-1.605771-1.381512.h5
# 190/190 [==============================] - 91s 477ms/step - loss: 1.6058 - mse: 70.9200 - mae: 2.8856 - val_loss: 1.3815 - val_mse: 53.4573 - val_mae: 2.5197
# Epoch 1103/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6038 - mse: 70.8175 - mae: 2.8845
# Epoch 01103: val_loss improved from 1.38151 to 1.37961, saving model to ./model_data/negative_Binomial_Unet_128x128IN_function/model-1103-1.603830-1.379606.h5
# 190/190 [==============================] - 91s 478ms/step - loss: 1.6038 - mse: 70.8175 - mae: 2.8845 - val_loss: 1.3796 - val_mse: 53.1545 - val_mae: 2.5165
# Epoch 1104/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6057 - mse: 71.0360 - mae: 2.8897
# Epoch 01104: val_loss improved from 1.37961 to 1.37843, saving model to ./model_data/negative_Binomial_Unet_128x128IN_function/model-1104-1.605693-1.378429.h5
# 190/190 [==============================] - 92s 487ms/step - loss: 1.6057 - mse: 71.0360 - mae: 2.8897 - val_loss: 1.3784 - val_mse: 52.7337 - val_mae: 2.5164
# 190/190 [==============================] - ETA: 0s - loss: 1.6054 - mse: 71.1119 - mae: 2.9115
# Epoch 01139: val_loss did not improve from 1.37557
# 190/190 [==============================] - 90s 475ms/step - loss: 1.6054 - mse: 71.1119 - mae: 2.9115 - val_loss: 1.3817 - val_mse: 53.3077 - val_mae: 2.5398
# Epoch 1140/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6056 - mse: 71.0896 - mae: 2.9082
# Epoch 01140: val_loss did not improve from 1.37557
# 190/190 [==============================] - 90s 475ms/step - loss: 1.6056 - mse: 71.0896 - mae: 2.9082 - val_loss: 1.3838 - val_mse: 53.3007 - val_mae: 2.5425
# Epoch 1141/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6054 - mse: 71.0517 - mae: 2.9100
# Epoch 01141: val_loss did not improve from 1.37557
# 190/190 [==============================] - 90s 476ms/step - loss: 1.6054 - mse: 71.0517 - mae: 2.9100 - val_loss: 1.3790 - val_mse: 53.3441 - val_mae: 2.5358
# Epoch 1142/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6041 - mse: 70.9982 - mae: 2.9087
# Epoch 01142: val_loss improved from 1.37557 to 1.37170, saving model to ./model_data/negative_Binomial_Unet_128x128IN_function/model-1142-1.604054-1.371701.h5
# 190/190 [==============================] - 91s 481ms/step - loss: 1.6041 - mse: 70.9982 - mae: 2.9087 - val_loss: 1.3717 - val_mse: 52.1922 - val_mae: 2.5183
# Epoch 1143/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6064 - mse: 71.2368 - mae: 2.9126
# Epoch 01143: val_loss did not improve from 1.37170
# 190/190 [==============================] - 91s 478ms/step - loss: 1.6064 - mse: 71.2368 - mae: 2.9126 - val_loss: 1.3792 - val_mse: 52.8610 - val_mae: 2.5352
# Epoch 1144/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6067 - mse: 71.2144 - mae: 2.9143
# Epoch 01144: val_loss did not improve from 1.37170
# 190/190 [==============================] - 93s 488ms/step - loss: 1.6067 - mse: 71.2144 - mae: 2.9143 - val_loss: 1.3844 - val_mse: 53.4314 - val_mae: 2.5440
# Epoch 1145/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6051 - mse: 71.1438 - mae: 2.9124
# Epoch 01145: val_loss did not improve from 1.37170
# 190/190 [==============================] - 92s 486ms/step - loss: 1.6051 - mse: 71.1438 - mae: 2.9124 - val_loss: 1.3847 - val_mse: 53.5702 - val_mae: 2.5470
# Epoch 1146/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6050 - mse: 71.0900 - mae: 2.9095
# Epoch 01146: val_loss did not improve from 1.37170
# 190/190 [==============================] - 91s 478ms/step - loss: 1.6050 - mse: 71.0900 - mae: 2.9095 - val_loss: 1.3791 - val_mse: 53.2332 - val_mae: 2.5359
# Epoch 1147/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6036 - mse: 70.8907 - mae: 2.9071
# Epoch 01147: val_loss did not improve from 1.37170
# 190/190 [==============================] - 93s 487ms/step - loss: 1.6036 - mse: 70.8907 - mae: 2.9071 - val_loss: 1.3803 - val_mse: 53.1922 - val_mae: 2.5361
# Epoch 1148/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6042 - mse: 70.9128 - mae: 2.9080
# Epoch 01148: val_loss did not improve from 1.37170
# 190/190 [==============================] - 93s 492ms/step - loss: 1.6042 - mse: 70.9128 - mae: 2.9080 - val_loss: 1.3820 - val_mse: 53.4684 - val_mae: 2.5402
# Epoch 1149/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6042 - mse: 70.9208 - mae: 2.9070
# Epoch 01149: val_loss did not improve from 1.37170
# 190/190 [==============================] - 90s 472ms/step - loss: 1.6042 - mse: 70.9208 - mae: 2.9070 - val_loss: 1.3737 - val_mse: 52.7671 - val_mae: 2.5238
# Epoch 1150/1150
# 190/190 [==============================] - ETA: 0s - loss: 1.6057 - mse: 71.0839 - mae: 2.9083
# Epoch 01150: val_loss did not improve from 1.37170
# 190/190 [==============================] - 91s 478ms/step - loss: 1.6057 - mse: 71.0839 - mae: 2.9083 - val_loss: 1.3847 - val_mse: 53.8111 - val_mae: 2.5463

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
history = trainer.history
def plotHistory():
    # Plot training & validation accuracy values
    plt.plot(history['mse'])
    plt.plot(history['val_mse'])
    plt.title('Model MSE')
    plt.ylabel('MSE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
plotHistory()

# %%
model = trainer.model
pred = None
label = None
pred_ = 20
test.on_epoch_end()
mean = []
stdev = []
label = []
prediction = []
for x,y in test:
    for i in range(batch_size):
        if y[i,:,:].max() > 0:
            pred = model(np.array([x[i,:,:,:]]))
            prediction.append(pred)
            mean.append(pred.mean())
            stdev.append(pred.stddev())
            label.append(y[i,:,:])
    if len(label) >= pred_:
        break
# Out:
# /home/simon/Dokumente/Teamprojekt/DeepRain2/Networks/Utils/transform.py:120: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return img[self.slices]

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
fig, axes = plt.subplots(20, 3, figsize=(16,8*10),dpi=64)
#fig.set_title(["mean","stdev","label"])
for batch,img in enumerate(mean):
    if batch == 20:
        break
    axes[batch,0].imshow(stdev[batch][0,:,:],cmap="gray")
    axes[batch,1].imshow(img[0,:,:],cmap="gray")
    axes[batch,2].imshow(label[batch][:,:],cmap="gray")

# %%
def map_Dist_To_Rain(prediction,label):
    
    x,y,t      = prediction[0][0,:,:,:].shape
    rain_true  = np.zeros((x,y,t))
    rain_false = rain_true.copy()
    
    
    
    ones = np.ones((x,y))
    zeros = np.zeros((x,y,t))
    value_map = np.array([ones * i/255 for i in range(256)])
    value_map = value_map.transpose(1,2,0)
    for i,pred in enumerate(prediction):
        ones = np.ones((x,y,t)) * 3/255
        #print((np.array(pred.prob(ones))).max(axis=-1) )
        probs = np.array(pred.prob(value_map))
        print(label[i].max())
        max_probs = probs.argmax(axis=-1)
        #print(probs[0,1,1,:].argmax())

        #print(probs.argmax(axis=-1))
        #print(probs.max(axis=-1))
        for j in range(64):
            for k in range(64):
                at = np.argmax(probs[0,k,j,:])
                if at > 0:
                #at = probs[0,k,j,:] .sum()
                    print("AATT",at)
        #    print(j,"min:",probs[:,:,:,j].min(),"max:",probs[:,:,:,j].max())
        #print(probs.shape)
        #print(probs)
        #print(pred.prob(0.0))
        print(np.array(pred.prob(label[i].max())).max() )
        print(np.array(pred.prob(label[i].max())).min() )
        if label[i].max() == 0:
            continue

        print(pred)
        s = (1-pred.cdf(zeros))
        
        #print(np.array(s).max(),np.array(probs.mean()).max(),label[i].max())
        
        plt.imshow(max_probs[0,:,:],cmap="gray")
        plt.show()
        plt.imshow(s[0,:,:,0],cmap="gray")
        plt.show()
        plt.imshow(label[i][:,:,0],cmap="gray")
        plt.show()
        break
    

#map_Dist_To_Rain(prediction,label)
print(prediction[0])
# Out:
# tfp.distributions.Independent("model_DistributionLayer_Independentmodel_DistributionLayer_NegativeBinomial", batch_shape=[1, 64, 64], event_shape=[], dtype=float32)

# %%
x = np.arange(50)

pred = prediction[0]
lab = label[0]

max_value = lab.max()
prob = np.array(pred.prob(max_value))
print(prob.shape,lab.shape)
idc = np.where(lab == max_value)
print(prob[0,:,:][idc])
prob_z = np.array(pred.prob(0))
print(prob_z[0,:,:][idc])


y = [ np.array(-pred.log_prob(i))[0,:,:][idc][0] for i in x]
print(y)
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(20,8.27)})
sns.barplot(x,y)
plt.show()
plt.imshow(lab[:,:])
plt.show()

plt.imshow(pred.mean()[0,:,:])
plt.show()
plt.imshow(np.array(-pred.prob(lab))[0,:,:])
# Out:
# (1, 64, 64) (64, 64)
# [0.00445094 0.0044539  0.00445664]
# [0.47916728 0.4790959  0.47903007]
# [0.7357055, 1.5434524, 2.1290102, 2.6502686, 3.1408641, 3.613503, 4.0743475, 4.526852, 4.9731474, 5.4146395, 5.8523016, 6.286849, 6.7188005, 7.148568, 7.5764627, 8.002732, 8.427592, 8.851205, 9.273717, 9.695226, 10.115853, 10.535676, 10.954766, 11.373193, 11.791009, 12.208261, 12.624993, 13.041257, 13.457059, 13.87246, 14.287473, 14.7021265, 15.116437, 15.530435, 15.944127, 16.357529, 16.770687, 17.183586, 17.59622, 18.008661, 18.420881, 18.832895, 19.244719, 19.656343, 20.067778, 20.479067, 20.890203, 21.301172, 21.711988, 22.122667]

# %%
print(prediction[0])
# Out:
# tfp.distributions.Independent("model_DistributionLayer_Independentmodel_DistributionLayer_NegativeBinomial", batch_shape=[1, 64, 64], event_shape=[], dtype=float32)
